# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.naive_bayes import GaussianNB

# %%
#
# %store -r train_X
# %store -r test_X
# %store -r valid_X

# %%
train_X.head()
# Out:
#          fips    PRECTOT          PS       QV2M        T2M     T2MDEW  \
# 0  32800768.0  522649.60  3286302.72  210370.56  373555.20  199557.12
# 1  32800768.0   43581.44  3289907.20  217251.84  376176.64  256901.12
# 2  32800768.0   36372.48  3289579.52  312279.04  467927.04  434503.68
# 3  32800768.0       0.00  3280404.48   67174.40  -25559.04 -259850.24
# 4  32800768.0       0.00  3309568.00  110100.48   67502.08  -56688.64
#
#       T2MWET    T2M_MAX    T2M_MIN         TS      WS10M  WS10M_MAX  \
# 0  199884.80  592773.12   70778.88  370606.08  125829.12  185794.56
# 1  256901.12  618659.84  187432.96  341770.24   57671.68   81264.64
# 2  434503.68  591134.72  294256.64  464977.92   86179.84  117964.80
# 3 -252968.96  185139.20 -178913.28  -19988.48  109772.80  150405.12
# 4  -55705.60  361103.36 -137953.28   61603.84   66519.04   89784.32
#
#    WS10M_MIN      WS50M  WS50M_MAX  WS50M_MIN    score        year    month  \
# ...
