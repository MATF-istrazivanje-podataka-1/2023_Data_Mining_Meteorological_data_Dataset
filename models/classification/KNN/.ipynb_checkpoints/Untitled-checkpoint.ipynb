# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
from sklearn.metrics import roc_curve
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import cohen_kappa_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

# %%
# bez resamplovanja
# %store -r X_train
# %store -r X_test
# %store -r y_train
# %store -r y_test
# sa SMOTE upsamplovanjem
# %store -r X_train_smote
# %store -r y_train_smote
# sa SMOTE upsamplovanjem i PCA
# %store -r X_train_smote_pca
# %store -r X_test_smote_pca
# sa SMOTE upsamplovanjem i LDA
# %store -r X_train_smote_lda
# %store -r X_test_smote_lda

# %%
# KNN bez resamplovanja
# KNN gde je n = 3
# daje dobre rezultate
knn_classifier_3 = KNeighborsClassifier(n_neighbors = 3, p = 2, metric = 'minkowski')
knn_classifier_3.fit(X_train, y_train)
y_pred_knn_3 = knn_classifier_3.predict(X_test)

# %%
print('Performanse KNN za 3 suseda bez resamplovanja:\n')
print(confusion_matrix(y_test, y_pred_knn_3))
print('\n')
print(classification_report(y_test, y_pred_knn_3))
print('\n')
print('Accuracy:', round(accuracy_score(y_test, y_pred_knn_3), 5))
print('Precision:', round(precision_score(y_test, y_pred_knn_3, average='weighted'), 5))
print('Recall:', round(recall_score(y_test, y_pred_knn_3, average='weighted'), 5))
print('F1 Score:', round(f1_score(y_test, y_pred_knn_3, average='weighted'), 5))
print('Cohen Kappa Score:',cohen_kappa_score(y_test, y_pred_knn_3))
# Out:
# Performanse KNN za 3 suseda bez resamplovanja:
#
# [[284263  15327   2454    973    387    131]
#  [ 24423  50672   8305   1161    326     68]
#  [  7731  10988  28871   5338    711    111]
#  [  3509   2857   6783  19165   2929    267]
#  [  1571    931   1616   3663   9948   1276]
#  [   454    243    304    522   1353   4480]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91    303535
#            1       0.63      0.60      0.61     84955
#            2       0.60      0.54      0.57     53750
#            3       0.62      0.54      0.58     35510
#            4       0.64      0.52      0.57     19005
#            5       0.71      0.61      0.65      7356
#
#     accuracy                           0.79    504111
#    macro avg       0.68      0.62      0.65    504111
# weighted avg       0.78      0.79      0.78    504111
#
#
#
# Accuracy: 0.78832
# Precision: 0.77881
# Recall: 0.78832
# F1 Score: 0.7824
# ...

# %%
fp_rate = dict()
tp_rate = dict()

for i in range(6):    
    fp_rate[i], tp_rate[i], _ = roc_curve(y_test, y_pred_knn_3, pos_label=i)

plt.plot(fp_rate[0], tp_rate[0], linestyle='--',color='orange', label='0-ti protiv ostalih')
plt.plot(fp_rate[1], tp_rate[1], linestyle='--',color='purple', label='1-vi protiv ostalih')
plt.plot(fp_rate[2], tp_rate[2], linestyle='--',color='red', label='2-gi protiv ostalih')
plt.plot(fp_rate[3], tp_rate[3], linestyle='--',color='gray', label='3-ći protiv ostalih')
plt.plot(fp_rate[4], tp_rate[4], linestyle='--',color='darkblue', label='4-ti protiv ostalih')
plt.plot(fp_rate[5], tp_rate[5], linestyle='--',color='green', label='5-ti protiv ostalih')

plt.title('ROC za KNN za 3 suseda bez resamplovanja')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend(loc='best')

# %%
#postavljanje hiperparametara
k_range = list(range(1, 5))
param_grid = dict(n_neighbors = k_range)

grid = GridSearchCV(knn_classifier_3, param_grid, cv = 2, scoring = 'accuracy', verbose = 3)
grid_search = grid.fit(X_train, y_train)
# Out:
# Fitting 2 folds for each of 4 candidates, totalling 8 fits
# [CV 1/2] END .....................n_neighbors=1;, score=0.770 total time=11.2min
# [CV 2/2] END .....................n_neighbors=1;, score=0.770 total time=11.3min
# [CV 1/2] END .....................n_neighbors=2;, score=0.755 total time=11.3min
# [CV 2/2] END .....................n_neighbors=2;, score=0.755 total time=11.5min
# [CV 1/2] END .....................n_neighbors=3;, score=0.749 total time=11.4min
# [CV 2/2] END .....................n_neighbors=3;, score=0.749 total time=11.3min
# [CV 1/2] END .....................n_neighbors=4;, score=0.747 total time=11.4min
# [CV 2/2] END .....................n_neighbors=4;, score=0.747 total time=11.3min

# %%
score_df = pd.DataFrame(grid_search.cv_results_)
score_df.nlargest(4,"mean_test_score")
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.130360      0.005938       674.524684        2.462763
# 1       0.131355      0.005837       685.289649        4.711546
# 2       0.139229      0.005006       681.879068        2.862364
# 3       0.133799      0.000703       680.816975        2.733970
#
#   param_n_neighbors              params  split0_test_score  split1_test_score  \
# 0                 1  {'n_neighbors': 1}           0.770027           0.769722
# 1                 2  {'n_neighbors': 2}           0.754977           0.755459
# 2                 3  {'n_neighbors': 3}           0.749421           0.749295
# 3                 4  {'n_neighbors': 4}           0.746805           0.747027
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.769875        0.000153                1
# 1         0.755218        0.000241                2
# 2         0.749358        0.000063                3
# ...

# %%
knn_classifier = KNeighborsClassifier(n_neighbors = 1, p = 2, metric = 'minkowski')
knn_classifier.fit(X_train, y_train)
y_pred_knn = knn_classifier.predict(X_test)

# %%
print('Performanse KNN za 1 suseda bez resamplovanja posle postavljanja hiperparametara:\n')
print(confusion_matrix(y_test, y_pred_knn))
print('\n')
print(classification_report(y_test, y_pred_knn))
print('\n')
print('Accuracy:', round(accuracy_score(y_test, y_pred_knn), 5))
print('Precision:', round(precision_score(y_test, y_pred_knn, average='weighted'), 5))
print('Recall:', round(recall_score(y_test, y_pred_knn, average='weighted'), 5))
print('F1 Score:', round(f1_score(y_test, y_pred_knn, average='weighted'), 5))
print('Cohen Kappa Score:',cohen_kappa_score(y_test, y_pred_knn))
# Out:
# Performanse KNN za 1 suseda bez resamplovanja posle postavljanja hiperparametara:
#
# [[281298  17271   2996   1293    538    139]
#  [ 17474  55247  10089   1585    473     87]
#  [  3259  10087  32572   6787    881    164]
#  [  1354   1504   6754  21670   3850    378]
#  [   561    444    917   3958  11559   1566]
#  [   145    117    162    333   1627   4972]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93    303535
#            1       0.65      0.65      0.65     84955
#            2       0.61      0.61      0.61     53750
#            3       0.61      0.61      0.61     35510
#            4       0.61      0.61      0.61     19005
#            5       0.68      0.68      0.68      7356
#
#     accuracy                           0.81    504111
#    macro avg       0.68      0.68      0.68    504111
# weighted avg       0.81      0.81      0.81    504111
#
#
#
# Accuracy: 0.80799
# Precision: 0.80768
# ...

# %%
fp_rate = dict()
tp_rate = dict()

for i in range(6):    
    fp_rate[i], tp_rate[i], _ = roc_curve(y_test, y_pred_knn, pos_label=i)

plt.plot(fp_rate[0], tp_rate[0], linestyle='--',color='orange', label='0-ti protiv ostalih')
plt.plot(fp_rate[1], tp_rate[1], linestyle='--',color='purple', label='1-vi protiv ostalih')
plt.plot(fp_rate[2], tp_rate[2], linestyle='--',color='red', label='2-gi protiv ostalih')
plt.plot(fp_rate[3], tp_rate[3], linestyle='--',color='gray', label='3-ći protiv ostalih')
plt.plot(fp_rate[4], tp_rate[4], linestyle='--',color='darkblue', label='4-ti protiv ostalih')
plt.plot(fp_rate[5], tp_rate[5], linestyle='--',color='green', label='5-ti protiv ostalih')

plt.title('ROC za KNN za 1 suseda bez resamplovanja posle postavljanja hiperparametara')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend(loc='best')

# %%
# KNN sa SMOTE
# KNN gde je n = 1
# daje dobre rezultate
knn_classifier_smote = KNeighborsClassifier(n_neighbors = 1, p = 2, metric = 'minkowski')
knn_classifier_smote.fit(X_train_smote, y_train_smote)
y_pred_knn_smote = knn_classifier_smote.predict(X_test)

# %%
print('Performanse KNN za 1 suseda sa SMOTE:\n')
print(confusion_matrix(y_test, y_pred_knn_smote))
print('\n')
print(classification_report(y_test, y_pred_knn_smote))
print('\n')
print('Accuracy:', round(accuracy_score(y_test, y_pred_knn_smote), 5))
print('Precision:', round(precision_score(y_test, y_pred_knn_smote, average='weighted'), 5))
print('Recall:', round(recall_score(y_test, y_pred_knn_smote, average='weighted'), 5))
print('F1 Score:', round(f1_score(y_test, y_pred_knn_smote, average='weighted'), 5))
print('Cohen Kappa Score:',cohen_kappa_score(y_test, y_pred_knn_smote))
# Out:
# Performanse KNN za 1 suseda sa SMOTE:
#
# [[277163  19625   3885   1793    831    238]
#  [ 15051  56657  10594   1889    602    162]
#  [  2298   9658  33445   7098   1035    216]
#  [   839   1303   6525  22356   4050    437]
#  [   333    322    804   3830  12109   1607]
#  [    77     90    135    308   1603   5143]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.91      0.92    303535
#            1       0.65      0.67      0.66     84955
#            2       0.60      0.62      0.61     53750
#            3       0.60      0.63      0.61     35510
#            4       0.60      0.64      0.62     19005
#            5       0.66      0.70      0.68      7356
#
#     accuracy                           0.81    504111
#    macro avg       0.67      0.69      0.68    504111
# weighted avg       0.81      0.81      0.81    504111
#
#
#
# Accuracy: 0.80711
# Precision: 0.812
# Recall: 0.80711
# F1 Score: 0.80936
# ...

# %%
fp_rate = dict()
tp_rate = dict()

for i in range(6):    
    fp_rate[i], tp_rate[i], _ = roc_curve(y_test, y_pred_knn_smote, pos_label=i)

plt.plot(fp_rate[0], tp_rate[0], linestyle='--',color='orange', label='0-ti protiv ostalih')
plt.plot(fp_rate[1], tp_rate[1], linestyle='--',color='purple', label='1-vi protiv ostalih')
plt.plot(fp_rate[2], tp_rate[2], linestyle='--',color='red', label='2-gi protiv ostalih')
plt.plot(fp_rate[3], tp_rate[3], linestyle='--',color='gray', label='3-ći protiv ostalih')
plt.plot(fp_rate[4], tp_rate[4], linestyle='--',color='darkblue', label='4-ti protiv ostalih')
plt.plot(fp_rate[5], tp_rate[5], linestyle='--',color='green', label='5-ti protiv ostalih')

plt.title('ROC za KNN za 1 suseda sa SMOTE')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend(loc='best')

# %%
# KNN sa SMOTE i PCA
# KNN gde je n = 1
# daje dobre rezultate
knn_classifier_smote_pca = KNeighborsClassifier(n_neighbors = 1, p = 2, metric = 'minkowski')
knn_classifier_smote_pca.fit(X_train_smote_pca, y_train_smote)
y_pred_knn_smote_pca = knn_classifier_smote_pca.predict(X_test_smote_pca)

# %%
print('Performanse KNN za 1 suseda sa SMOTE i PCA:\n')
print(confusion_matrix(y_test, y_pred_knn_smote_pca))
print('\n')
print(classification_report(y_test, y_pred_knn_smote_pca))
print('\n')
print('Accuracy:', round(accuracy_score(y_test, y_pred_knn_smote_pca), 5))
print('Precision:', round(precision_score(y_test, y_pred_knn_smote_pca, average='weighted'), 5))
print('Recall:', round(recall_score(y_test, y_pred_knn_smote_pca, average='weighted'), 5))
print('F1 Score:', round(f1_score(y_test, y_pred_knn_smote_pca, average='weighted'), 5))
print('Cohen Kappa Score:',cohen_kappa_score(y_test, y_pred_knn_smote_pca))
# Out:
# Performanse KNN za 1 suseda sa SMOTE i PCA:
#
# [[271388  21806   5673   2932   1284    452]
#  [ 16377  54465  10724   2381    787    221]
#  [  3375   9770  31824   7188   1284    309]
#  [  1349   1664   6568  21267   4164    498]
#  [   534    511    971   3819  11551   1619]
#  [   186    129    186    359   1568   4928]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91    303535
#            1       0.62      0.64      0.63     84955
#            2       0.57      0.59      0.58     53750
#            3       0.56      0.60      0.58     35510
#            4       0.56      0.61      0.58     19005
#            5       0.61      0.67      0.64      7356
#
#     accuracy                           0.78    504111
#    macro avg       0.64      0.67      0.65    504111
# weighted avg       0.79      0.78      0.79    504111
#
#
#
# Accuracy: 0.7844
# Precision: 0.79139
# Recall: 0.7844
# F1 Score: 0.78757
# ...

# %%
fp_rate = dict()
tp_rate = dict()

for i in range(6):    
    fp_rate[i], tp_rate[i], _ = roc_curve(y_test, y_pred_knn_smote_pca, pos_label=i)

plt.plot(fp_rate[0], tp_rate[0], linestyle='--',color='orange', label='0-ti protiv ostalih')
plt.plot(fp_rate[1], tp_rate[1], linestyle='--',color='purple', label='1-vi protiv ostalih')
plt.plot(fp_rate[2], tp_rate[2], linestyle='--',color='red', label='2-gi protiv ostalih')
plt.plot(fp_rate[3], tp_rate[3], linestyle='--',color='gray', label='3-ći protiv ostalih')
plt.plot(fp_rate[4], tp_rate[4], linestyle='--',color='darkblue', label='4-ti protiv ostalih')
plt.plot(fp_rate[5], tp_rate[5], linestyle='--',color='green', label='5-ti protiv ostalih')

plt.title('ROC za KNN za 1 suseda sa SMOTE i PCA')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend(loc='best')

# %%
# KNN sa SMOTE i LDA
# KNN gde je n = 1
# daje dobre rezultate
knn_classifier_smote_lda = KNeighborsClassifier(n_neighbors = 1, p = 2, metric = 'minkowski')
knn_classifier_smote_lda.fit(X_train_smote_lda, y_train_smote)
y_pred_knn_smote_lda = knn_classifier_smote_lda.predict(X_test_smote_lda)

# %%
print('Performanse KNN za 1 suseda sa SMOTE i LDA:\n')
print(confusion_matrix(y_test, y_pred_knn_smote_lda))
print('\n')
print(classification_report(y_test, y_pred_knn_smote_lda))
print('\n')
print('Accuracy:', round(accuracy_score(y_test, y_pred_knn_smote_lda), 5))
print('Precision:', round(precision_score(y_test, y_pred_knn_smote_lda, average='weighted'), 5))
print('Recall:', round(recall_score(y_test, y_pred_knn_smote_lda, average='weighted'), 5))
print('F1 Score:', round(f1_score(y_test, y_pred_knn_smote_lda, average='weighted'), 5))
print('Cohen Kappa Score:', cohen_kappa_score(y_test, y_pred_knn_smote_lda))
# Out:
# Performanse KNN za 1 suseda sa SMOTE i LDA:
#
# [[214862  36522  22188  15936   9642   4385]
#  [ 17774  43262  12053   6124   3954   1788]
#  [  6242   9778  25545   7477   3227   1481]
#  [  3398   3487   6322  16672   4322   1309]
#  [  1466   1552   1863   3563   8930   1631]
#  [   500    498    584    694   1344   3736]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.71      0.78    303535
#            1       0.45      0.51      0.48     84955
#            2       0.37      0.48      0.42     53750
#            3       0.33      0.47      0.39     35510
#            4       0.28      0.47      0.35     19005
#            5       0.26      0.51      0.34      7356
#
#     accuracy                           0.62    504111
#    macro avg       0.43      0.52      0.46    504111
# weighted avg       0.68      0.62      0.64    504111
#
#
#
# Accuracy: 0.62091
# Precision: 0.68387
# Recall: 0.62091
# F1 Score: 0.64358
# ...

# %%
fp_rate = dict()
tp_rate = dict()

for i in range(6):    
    fp_rate[i], tp_rate[i], _ = roc_curve(y_test, y_pred_knn_smote_lda, pos_label=i)

plt.plot(fp_rate[0], tp_rate[0], linestyle='--',color='orange', label='0-ti protiv ostalih')
plt.plot(fp_rate[1], tp_rate[1], linestyle='--',color='purple', label='1-vi protiv ostalih')
plt.plot(fp_rate[2], tp_rate[2], linestyle='--',color='red', label='2-gi protiv ostalih')
plt.plot(fp_rate[3], tp_rate[3], linestyle='--',color='gray', label='3-ći protiv ostalih')
plt.plot(fp_rate[4], tp_rate[4], linestyle='--',color='darkblue', label='4-ti protiv ostalih')
plt.plot(fp_rate[5], tp_rate[5], linestyle='--',color='green', label='5-ti protiv ostalih')

plt.title('ROC za KNN za 1 suseda sa SMOTE i LDA')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend(loc='best')

# %%
#čuvamo za fajl za upoređivanje modela
# %store y_pred_knn
# %store y_pred_knn_smote
# %store y_pred_knn_smote_pca
# %store y_pred_knn_smote_lda
# Out:
# Stored 'y_pred_knn' (ndarray)
# Stored 'y_pred_knn_smote' (ndarray)
# Stored 'y_pred_knn_smote_pca' (ndarray)
# Stored 'y_pred_knn_smote_lda' (ndarray)
